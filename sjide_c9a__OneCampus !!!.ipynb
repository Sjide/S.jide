# %% [markdown]
# Project Brief

# %% [markdown]
# Crime in Chicago has been worrisome to the Chicago PD. Reported crimes have been tracked on a daily basis since 2001 and have been provided in the project data file. The Chicago PD would like to drastically reduce the spate of violent crimes reported in the city. Being effective involves knowing crime patterns and where they are likely to occur. It also involves equipping the Police Department appropriately. They have recruited you to conduct full data analytics and uncover insights from the data that can be used to effectively prepare for and respond to crimes. They are interested in gleaning any insights that can help them determine What type of crimes to prepare for, Where these crimes are most likely to occur, What days of the week and periods to expect these crimes

# %% [markdown]
# Task

# %% [markdown]
# Conduct a complete data analytics study and from your analytics, advise the Chicago PD accordingly

# %% [markdown]
# SULEIMAN ITOPA JIDE
#
# sjide_c9a__onecampus
#
# ID number: 50009

# %% [markdown]
# PROGRAM FINAL PROJECT

# %% [markdown]
# Exploratory Analysis on Chicago Crime data (2001 - 2022)

# %% [markdown]
# import libraries

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates

# %%
df = pd.read_csv('c:/datasets/crime_data_Proj1.csv')
df.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date  \
# 0           0   6407111    HP485721  07/26/2008 02:30:00 PM
# 1           1  11398199    JB372830  07/31/2018 10:57:00 AM
# 2           2   5488785    HN308568  04/27/2007 10:30:00 AM
# 3           3  11389116    JB361368  07/23/2018 08:55:00 AM
# 4           4  12420431    JE297624  07/11/2021 06:40:00 AM
#
#                   Block  IUCR       Primary Type               Description  \
# 0  085XX S MUSKEGON AVE  1320    CRIMINAL DAMAGE                TO VEHICLE
# 1     092XX S ELLIS AVE  143C  WEAPONS VIOLATION  UNLAWFUL POSS AMMUNITION
# 2     062XX N TRIPP AVE  0610           BURGLARY            FORCIBLE ENTRY
# 3    0000X N KEELER AVE  0560            ASSAULT                    SIMPLE
# 4   016XX W HARRISON ST  051A            ASSAULT      AGGRAVATED - HANDGUN
#
#                      Location Description  Arrest  ...  Ward  Community Area  \
# 0                                  STREET   False  ...  10.0            46.0
# 1                               POOL ROOM    True  ...   8.0            47.0
# 2                               RESIDENCE    True  ...  39.0            12.0
# 3            NURSING HOME/RETIREMENT HOME   False  ...  28.0            26.0
# 4  PARKING LOT / GARAGE (NON RESIDENTIAL)   False  ...  27.0            28.0
#
#    FBI Code  X Coordinate  Y Coordinate  Year              Updated On  \
# 0        14     1196638.0     1848800.0  2008  02/28/2018 03:56:25 PM
# 1        15     1184499.0     1843935.0  2018  08/07/2018 04:02:59 PM
# 2        05     1146911.0     1941022.0  2007  02/28/2018 03:56:25 PM
# 3       08A     1148388.0     1899882.0  2018  07/30/2018 03:52:24 PM
# 4       04A     1165430.0     1897441.0  2021  07/18/2021 04:56:02 PM
#
#     Latitude  Longitude                       Location
# 0  41.739980 -87.555120  (41.739979622, -87.555120042)
# 1  41.726922 -87.599747  (41.726922145, -87.599746995)
# 2  41.994138 -87.734959  (41.994137622, -87.734959049)
# 3  41.881217 -87.730590  (41.881217483, -87.730589961)
# 4  41.874174 -87.668082  (41.874173691, -87.668082118)
#
# [5 rows x 23 columns]

# %% [markdown]
# To Check dataframe structure and properties

# %% [markdown]
# Columns & their descriptions included in my main data frame:

# %% [markdown]
# Number: Row number used as an index

# %% [markdown]
# ID: Unique numeric ID

# %% [markdown]
# Case Number: Unique numeric/letter based ID

# %% [markdown]
# Date: Datestamp in MM/DD/YYYY, HH:MM:SS day and time format

# %% [markdown]
# Block: Block of crime with street number and street, only showing first 3 digits of street number for privacy. ex) 013XX S Sawyer Ave

# %% [markdown]
# IUCR: 4 digit crime reference number, non-unique

# %% [markdown]
# Primary_Type: Short crime description/categorization

# %% [markdown]
# Description: Longer explanation of crime (1–5 words typically)

# %% [markdown]
# Location_Description: Short location description/categorization

# %% [markdown]
# Arrest: True or False

# %% [markdown]
# Domestic: True or False

# %% [markdown]
# X Coordinate: X coordinate of the location

# %% [markdown]
# Y Coordinate: Y coordinate of the location

# %% [markdown]
# Latitude: Latitude of location

# %% [markdown]
# Longitude: Longitude of Location

# %% [markdown]
# Year: Year crime occurred

# %%
df.shape
# Out:
# (2278726, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2278726 entries, 0 to 2278725
# Data columns (total 23 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   ID                    int64
#  2   Case Number           object
#  3   Date                  object
#  4   Block                 object
#  5   IUCR                  object
#  6   Primary Type          object
#  7   Description           object
#  8   Location Description  object
#  9   Arrest                bool
#  10  Domestic              bool
#  11  Beat                  int64
#  12  District              float64
#  13  Ward                  float64
#  14  Community Area        float64
#  15  FBI Code              object
#  16  X Coordinate          float64
#  17  Y Coordinate          float64
#  18  Year                  int64
#  19  Updated On            object
#  20  Latitude              float64
#  21  Longitude             float64
#  22  Location              object
# dtypes: bool(2), float64(7), int64(4), object(10)
# memory usage: 369.4+ MB

# %% [markdown]
# We observe that our dataset has a combination of categorical (object) and numeric (float and int) features. At this point, I went back to the data dictionary for an understanding of the columns and their meanings.

# %%
df.describe().T
# Out:
#                     count          mean           std          min  \
# Unnamed: 0      2278726.0  1.139362e+06  6.578117e+05     0.000000
# ID              2278726.0  6.882068e+06  3.419168e+06   637.000000
# Beat            2278726.0  1.186442e+03  7.026836e+02   111.000000
# District        2278714.0  1.129072e+01  6.946692e+00     1.000000
# Ward            2094031.0  2.272764e+01  1.383464e+01     1.000000
# Community Area  2094459.0  3.752140e+01  2.153282e+01     0.000000
# X Coordinate    2254741.0  1.164569e+06  1.673955e+04     0.000000
# Y Coordinate    2254741.0  1.885747e+06  3.209855e+04     0.000000
# Year            2278726.0  2.009638e+03  6.019724e+00  2001.000000
# Latitude        2254741.0  4.184209e+01  8.830434e-02    36.619446
# Longitude       2254741.0 -8.767161e+01  6.073538e-02   -91.686566
#
#                          25%           50%           75%           max
# Unnamed: 0      5.696812e+05  1.139362e+06  1.709044e+06  2.278725e+06
# ID              3.716076e+06  6.885990e+06  9.887568e+06  1.278199e+07
# Beat            6.210000e+02  1.034000e+03  1.731000e+03  2.535000e+03
# District        6.000000e+00  1.000000e+01  1.700000e+01  3.100000e+01
# Ward            1.000000e+01  2.300000e+01  3.400000e+01  5.000000e+01
# Community Area  2.300000e+01  3.200000e+01  5.700000e+01  7.700000e+01
# X Coordinate    1.152948e+06  1.166060e+06  1.176365e+06  1.205119e+06
# Y Coordinate    1.859053e+06  1.890673e+06  1.909219e+06  1.951622e+06
# Year            2.004000e+03  2.009000e+03  2.014000e+03  2.022000e+03
# Latitude        4.176866e+01  4.185578e+01  4.190668e+01  4.202291e+01
# Longitude      -8.771379e+01 -8.766597e+01 -8.762823e+01 -8.752453e+01

# %% [markdown]
# We can see for each numeric feature, the count of values in it, the mean value, std or standard deviation, minimum value, the 25th percentile, the 50th percentile or median, the 75th percentile, and the maximum value. From the count we can also identify the features with missing values; their count is not equal to the total number of rows of the dataset.

# %%
#To check the summary statistics of only the categorical features, we will use 
df.describe(include=object)
# Out:
#        Case Number                    Date             Block     IUCR  \
# count      2278725                 2278726           2278726  2278726
# unique     2278678                 1343546             54347      392
# top       HK172551  01/01/2008 12:01:00 AM  100XX W OHARE ST     0820
# freq             3                      81              4878   184891
#
#        Primary Type Description Location Description FBI Code  \
# count       2278726     2278726              2275849  2278726
# unique           35         515                  198       26
# top           THEFT      SIMPLE               STREET       06
# freq         479375      268418               590957   479375
#
#                     Updated On                       Location
# count                  2278726                        2254741
# unique                    4461                         545376
# top     02/10/2018 03:50:01 PM  (41.976290414, -87.905227221)
# freq                    836558                           4227

# %% [markdown]
# This table is a bit different from the one for numeric features. Here, we get the count of the values of each feature, the number of unique classes, the top most frequent class, and how frequently that class occurs in the data set.

# %% [markdown]
# We note that some classes have a lot of unique values such as Case Number, followed by Date and Location. Also from this finding, THEFT is the top most Primary Type of crime, followed by SIMPLE as being the Description and th top most Location Description happened to be STREET.

# %% [markdown]
# DATA CLEANING

# %% [markdown]
# Introduction Data Cleaning is the process of finding and correcting the inaccurate/incorrect data that are present in the dataset. One such process needed is to do something about the values that are missing in the dataset. In real life, many datasets will have many missing values, so dealing with them is an important step.

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                   0
# ID                           0
# Case Number                  1
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      2877
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    12
# Ward                    184695
# Community Area          184267
# FBI Code                     0
# X Coordinate             23985
# Y Coordinate             23985
# Year                         0
# Updated On                   0
# Latitude                 23985
# Longitude                23985
# Location                 23985
# dtype: int64

# %%
# df.apply(lambda col:pd.to_numeric(col, errors='coerce'))
for i in range(0, len(df.columns)):
    df.iloc[:,i] = pd.to_numeric(df.iloc[:,i], errors='ignore')
    # errors='ignore' lets strings remain as 'non-null objects'

# %%
types = df.dtypes
print(types)
# Out:
# Unnamed: 0                int64
# ID                        int64
# Case Number              object
# Date                     object
# Block                    object
# IUCR                     object
# Primary Type             object
# Description              object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# Beat                      int64
# District                float64
# Ward                    float64
# Community Area          float64
# FBI Code                 object
# X Coordinate            float64
# Y Coordinate            float64
# Year                      int64
# Updated On               object
# Latitude                float64
# Longitude               float64
# Location                 object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                   0
# ID                           0
# Case Number                  1
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      2877
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    12
# Ward                    184695
# Community Area          184267
# FBI Code                     0
# X Coordinate             23985
# Y Coordinate             23985
# Year                         0
# Updated On                   0
# Latitude                 23985
# Longitude                23985
# Location                 23985
# dtype: int64

# %%
# Deal with Missing Values
#First: Drop rows for categorical variables

# %% [markdown]
# categorical variables with missing values are: Case Number, Location Description, and Location

# %%
df = df.dropna(subset=['Case Number'])
df = df.dropna(subset=['Location Description'])
df = df.dropna(subset=['Location'])

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0                   0
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description         0
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    12
# Ward                    181938
# Community Area          181545
# FBI Code                     0
# X Coordinate                 0
# Y Coordinate                 0
# Year                         0
# Updated On                   0
# Latitude                     0
# Longitude                    0
# Location                     0
# dtype: int64

# %% [markdown]
# Next: Treating non-categoricals
# Use mean values

# %%
df['District'] = df['District'].fillna(df['District'].mean())
df['Ward'] = df['Ward'].fillna(df['Ward'].mean())
df['Community Area'] = df['Community Area'].fillna(df['Community Area'].mean())

# %%
print(df.isna().sum())
# Out:
# Unnamed: 0              0
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %% [markdown]
# To check colinearity of features using Heatmap.

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import set_option
data = df
 

set_option('display.width', 100)

plt.figure(figsize=(16,10))
#sns.heatmap(data.corr())

sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can observe the following colinearities: between Year and ID; Longitude and X- Coordinate; Latitude and Y- Coordinate. Features such as :X Coordinate, Y Coordinate, Latitude, Longitude have no bearing to crime prediction as they perform the same function as Location. I am dropping them.

# %%
df = df.drop(['ID', 'Case Number', 'IUCR', 'X Coordinate', 'Y Coordinate', 'Updated On','Latitude', 'Longitude'], axis = 1)

# %%
df
# Out:
#          Unnamed: 0                    Date                 Block       Primary Type  \
# 0                 0  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE    CRIMINAL DAMAGE
# 1                 1  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  WEAPONS VIOLATION
# 2                 2  04/27/2007 10:30:00 AM     062XX N TRIPP AVE           BURGLARY
# 3                 3  07/23/2018 08:55:00 AM    0000X N KEELER AVE            ASSAULT
# 4                 4  07/11/2021 06:40:00 AM   016XX W HARRISON ST            ASSAULT
# ...             ...                     ...                   ...                ...
# 2278721     2278721  10/14/2016 02:35:00 PM      006XX N CLARK ST            ASSAULT
# 2278722     2278722  09/11/2001 10:20:00 PM       052XX W LAKE ST            BATTERY
# 2278723     2278723  05/10/2006 07:49:00 PM  007XX E OAKWOOD BLVD            ASSAULT
# 2278724     2278724  10/18/2017 10:30:00 PM       002XX W ERIE ST  CRIMINAL TRESPASS
# 2278725     2278725  06/09/2004 08:19:28 PM   016XX N ROCKWELL ST          NARCOTICS
#
#                           Description                    Location Description  Arrest  Domestic  \
# 0                          TO VEHICLE                                  STREET   False     False
# 1            UNLAWFUL POSS AMMUNITION                               POOL ROOM    True     False
# 2                      FORCIBLE ENTRY                               RESIDENCE    True     False
# 3                              SIMPLE            NURSING HOME/RETIREMENT HOME   False     False
# 4                AGGRAVATED - HANDGUN  PARKING LOT / GARAGE (NON RESIDENTIAL)   False     False
# ...                               ...                                     ...     ...       ...
# 2278721                        SIMPLE                       CONVENIENCE STORE    True     False
# 2278722                        SIMPLE                               RESIDENCE   False      True
# 2278723                        SIMPLE                               APARTMENT   False      True
# 2278724                    TO VEHICLE          PARKING LOT/GARAGE(NON.RESID.)   False     False
# 2278725  POSS: CANNABIS 30GMS OR LESS                                  STREET    True     False
#
#          Beat  District       Ward  Community Area FBI Code  Year                       Location
# 0         423       4.0  10.000000       46.000000       14  2008  (41.739979622, -87.555120042)
# 1         413       4.0   8.000000       47.000000       15  2018  (41.726922145, -87.599746995)
# 2        1711      17.0  39.000000       12.000000       05  2007  (41.994137622, -87.734959049)
# 3        1115      11.0  28.000000       26.000000      08A  2018  (41.881217483, -87.730589961)
# 4        1231      12.0  27.000000       28.000000      04A  2021  (41.874173691, -87.668082118)
# ...       ...       ...        ...             ...      ...   ...                            ...
# 2278721  1832      18.0  42.000000        8.000000      08A  2016  (41.893646656, -87.631177143)
# 2278722  1523      15.0  22.713025       37.546407      08B  2001  (41.887188151, -87.757163155)
# 2278723   213       2.0   4.000000       38.000000      08A  2006   (41.82272748, -87.607863136)
# 2278724  1831      18.0  42.000000        8.000000       26  2017  (41.893983593, -87.634677382)
# 2278725  1434      14.0   1.000000       24.000000       18  2004   (41.91109424, -87.692122762)
#
# [2252872 rows x 15 columns]

# %%
df.describe().T
# Out:
#                     count          mean            std     min        25%           50%  \
# Unnamed: 0      2252872.0  1.139370e+06  657802.123277     0.0  569725.75  1.139344e+06
# Beat            2252872.0  1.186054e+03     702.583919   111.0     621.00  1.034000e+03
# District        2252872.0  1.128717e+01       6.945340     1.0       6.00  1.000000e+01
# Ward            2252872.0  2.271302e+01      13.258846     1.0      11.00  2.271302e+01
# Community Area  2252872.0  3.754641e+01      20.643814     0.0      24.00  3.754641e+01
# Year            2252872.0  2.009626e+03       6.007905  2001.0    2004.00  2.009000e+03
#
#                        75%        max
# Unnamed: 0      1708985.25  2278725.0
# Beat               1731.00     2535.0
# District             17.00       31.0
# Ward                 32.00       50.0
# Community Area       53.00       77.0
# Year               2014.00     2022.0

# %%
df.describe(include=object)
# Out:
#                           Date             Block Primary Type Description Location Description  \
# count                  2252872           2252872      2252872     2252872              2252872
# unique                 1334507             53378           35         513                  198
# top     01/01/2007 12:01:00 AM  100XX W OHARE ST        THEFT      SIMPLE               STREET
# freq                        53              4785       473224      267016               586599
#
#        FBI Code                       Location
# count   2252872                        2252872
# unique       26                         545167
# top          06  (41.976290414, -87.905227221)
# freq     473224                           4227

# %%
df.describe(include=bool)
# Out:
#          Arrest Domestic
# count   2252872  2252872
# unique        2        2
# top       False    False
# freq    1655000  1941710

# %% [markdown]
# We need to ennumerate the data for Arrest and Domestic numerically now. We will let 0 represent False and 1 represent True

# %%
df['Arrest'] = df['Arrest'].map( {True: 1, False: 0} ).astype(int)
df['Domestic'] = df['Domestic'].map( {True: 1, False: 0} ).astype(int)

# %%
df.head()
# Out:
#    Unnamed: 0                    Date                 Block       Primary Type  \
# 0           0  07/26/2008 02:30:00 PM  085XX S MUSKEGON AVE    CRIMINAL DAMAGE
# 1           1  07/31/2018 10:57:00 AM     092XX S ELLIS AVE  WEAPONS VIOLATION
# 2           2  04/27/2007 10:30:00 AM     062XX N TRIPP AVE           BURGLARY
# 3           3  07/23/2018 08:55:00 AM    0000X N KEELER AVE            ASSAULT
# 4           4  07/11/2021 06:40:00 AM   016XX W HARRISON ST            ASSAULT
#
#                 Description                    Location Description  Arrest  Domestic  Beat  \
# 0                TO VEHICLE                                  STREET       0         0   423
# 1  UNLAWFUL POSS AMMUNITION                               POOL ROOM       1         0   413
# 2            FORCIBLE ENTRY                               RESIDENCE       1         0  1711
# 3                    SIMPLE            NURSING HOME/RETIREMENT HOME       0         0  1115
# 4      AGGRAVATED - HANDGUN  PARKING LOT / GARAGE (NON RESIDENTIAL)       0         0  1231
#
#    District  Ward  Community Area FBI Code  Year                       Location
# 0       4.0  10.0            46.0       14  2008  (41.739979622, -87.555120042)
# 1       4.0   8.0            47.0       15  2018  (41.726922145, -87.599746995)
# 2      17.0  39.0            12.0       05  2007  (41.994137622, -87.734959049)
# 3      11.0  28.0            26.0      08A  2018  (41.881217483, -87.730589961)
# 4      12.0  27.0            28.0      04A  2021  (41.874173691, -87.668082118)

# %% [markdown]
# Primary Type is the type of crime committed...let's see what different types of crimes are there:

# %%
df['Primary Type'].unique()
# Out:
# array(['CRIMINAL DAMAGE', 'WEAPONS VIOLATION', 'BURGLARY', 'ASSAULT',
#        'THEFT', 'ROBBERY', 'NARCOTICS', 'MOTOR VEHICLE THEFT', 'BATTERY',
#        'OTHER OFFENSE', 'PROSTITUTION', 'DECEPTIVE PRACTICE',
#        'INTIMIDATION', 'INTERFERENCE WITH PUBLIC OFFICER',
#        'CRIMINAL TRESPASS', 'STALKING', 'OFFENSE INVOLVING CHILDREN',
#        'PUBLIC PEACE VIOLATION', 'SEX OFFENSE', 'CRIM SEXUAL ASSAULT',
#        'HOMICIDE', 'LIQUOR LAW VIOLATION', 'CRIMINAL SEXUAL ASSAULT',
#        'KIDNAPPING', 'ARSON', 'GAMBLING',
#        'CONCEALED CARRY LICENSE VIOLATION', 'PUBLIC INDECENCY',
#        'RITUALISM', 'OBSCENITY', 'NON - CRIMINAL',
#        'OTHER NARCOTIC VIOLATION', 'HUMAN TRAFFICKING', 'NON-CRIMINAL',
#        'NON-CRIMINAL (SUBJECT SPECIFIED)'], dtype=object)

# %% [markdown]
# We also need to look at Location Description and ennumerate it:

# %%
df['Location Description'].unique()
# Out:
# array(['STREET', 'POOL ROOM', 'RESIDENCE', 'NURSING HOME/RETIREMENT HOME',
#        'PARKING LOT / GARAGE (NON RESIDENTIAL)', 'CTA PLATFORM', 'ALLEY',
#        'POLICE FACILITY/VEH PARKING LOT', 'SIDEWALK', 'APARTMENT',
#        'OTHER', 'SPORTS ARENA/STADIUM', 'CHA APARTMENT',
#        'VEHICLE-COMMERCIAL', 'PARK PROPERTY',
#        'GOVERNMENT BUILDING/PROPERTY', 'BAR OR TAVERN',
#        'COMMERCIAL / BUSINESS OFFICE', 'CHA PARKING LOT/GROUNDS',
#        'SMALL RETAIL STORE', 'RESIDENCE PORCH/HALLWAY', 'VACANT LOT/LAND',
#        'VEHICLE NON-COMMERCIAL', 'DEPARTMENT STORE',
#        'PARKING LOT/GARAGE(NON.RESID.)', 'CTA TRAIN', 'RESIDENCE-GARAGE',
#        'DRUG STORE', 'HOSPITAL BUILDING/GROUNDS',
#        'RESIDENTIAL YARD (FRONT/BACK)', 'CTA BUS',
#        'SCHOOL, PUBLIC, BUILDING', 'RESTAURANT', 'GAS STATION',
#        'NEWSSTAND', 'RESIDENCE - YARD (FRONT / BACK)',
#        'TAVERN/LIQUOR STORE', 'RESIDENCE - PORCH / HALLWAY',
#        'CHURCH/SYNAGOGUE/PLACE OF WORSHIP', 'GROCERY FOOD STORE',
#        'CAR WASH', 'SCHOOL, PRIVATE, BUILDING', 'OTHER (SPECIFY)',
#        'CHA HALLWAY/STAIRWELL/ELEVATOR', 'AIRPORT/AIRCRAFT',
#        'ABANDONED BUILDING', 'CTA GARAGE / OTHER PROPERTY',
#        'CONSTRUCTION SITE', 'MOVIE HOUSE/THEATER', 'CURRENCY EXCHANGE',
#        'BARBERSHOP', 'GANGWAY', 'RESIDENCE - GARAGE', 'CONVENIENCE STORE',
#        'ATHLETIC CLUB', 'CTA BUS STOP', 'LIBRARY',
#        'AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA', 'HOTEL/MOTEL',
#        'SCHOOL, PUBLIC, GROUNDS', 'BANK', 'VEHICLE - OTHER RIDE SERVICE',
#        'DELIVERY TRUCK', 'OTHER RAILROAD PROP / TRAIN DEPOT',
#        'COIN OPERATED MACHINE', 'COLLEGE/UNIVERSITY RESIDENCE HALL',
#        'CLEANING STORE', 'COLLEGE/UNIVERSITY GROUNDS', 'WAREHOUSE',
#        'AUTO / BOAT / RV DEALERSHIP', 'DRIVEWAY - RESIDENTIAL',
#        'CTA STATION', 'HOSPITAL BUILDING / GROUNDS', 'DAY CARE CENTER',
#        'TAXICAB', 'VACANT LOT / LAND', 'ATM (AUTOMATIC TELLER MACHINE)',
#        'NURSING / RETIREMENT HOME', 'CREDIT UNION', 'AIRPORT PARKING LOT',
#        'FACTORY/MANUFACTURING BUILDING',
#        'AIRPORT TERMINAL UPPER LEVEL - SECURE AREA', 'APPLIANCE STORE',
#        'RETAIL STORE', 'OTHER RAILROAD PROPERTY / TRAIN DEPOT',
#        'AIRPORT TERMINAL LOWER LEVEL - SECURE AREA',
#        'MEDICAL / DENTAL OFFICE', 'SCHOOL - PUBLIC BUILDING',
#        'GOVERNMENT BUILDING / PROPERTY', 'HOTEL / MOTEL',
#        'LAKEFRONT/WATERFRONT/RIVERBANK',
#        'AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA',
#        'CHA PARKING LOT / GROUNDS', 'MOVIE HOUSE / THEATER',
#        'OTHER COMMERCIAL TRANSPORTATION', 'FEDERAL BUILDING',
#        'SCHOOL - PRIVATE GROUNDS',
#        'AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA',
#        'SCHOOL, PRIVATE, GROUNDS', 'AIRPORT VENDING ESTABLISHMENT',
#        'CEMETARY', 'FOREST PRESERVE', 'SCHOOL - PRIVATE BUILDING',
#        'POLICE FACILITY / VEHICLE PARKING LOT', 'JAIL / LOCK-UP FACILITY',
#        'MEDICAL/DENTAL OFFICE', 'HOUSE', 'HIGHWAY/EXPRESSWAY',
#        'TAVERN / LIQUOR STORE', 'SCHOOL - PUBLIC GROUNDS', 'FIRE STATION',
#        'LAKEFRONT / WATERFRONT / RIVERBANK', 'VEHICLE - DELIVERY TRUCK',
#        'AUTO', 'AIRPORT EXTERIOR - NON-SECURE AREA', 'SAVINGS AND LOAN',
#        'BOWLING ALLEY', 'PARKING LOT',
#        'CTA PARKING LOT / GARAGE / OTHER PROPERTY', 'BOAT/WATERCRAFT',
#        'VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER, LYFT)', 'YARD',
#        'CHURCH / SYNAGOGUE / PLACE OF WORSHIP', 'AIRCRAFT',
#        'ANIMAL HOSPITAL', 'OFFICE', 'BOAT / WATERCRAFT',
#        'CHA HALLWAY / STAIRWELL / ELEVATOR',
#        'AIRPORT BUILDING NON-TERMINAL - SECURE AREA',
#        'HIGHWAY / EXPRESSWAY', 'CHA GROUNDS',
#        'AIRPORT TRANSPORTATION SYSTEM (ATS)', 'PORCH',
#        'VEHICLE - OTHER RIDE SHARE SERVICE (LYFT, UBER, ETC.)',
#        'AIRPORT EXTERIOR - SECURE AREA', 'BRIDGE', 'CHA HALLWAY',
#        'VEHICLE - COMMERCIAL', 'VACANT LOT', 'GARAGE', 'PAWN SHOP',
#        'FACTORY / MANUFACTURING BUILDING', 'CHURCH',
#        'GAS STATION DRIVE/PROP.', 'CTA TRACKS - RIGHT OF WAY',
#        'SPORTS ARENA / STADIUM', 'HALLWAY',
#        'AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA',
#        'BARBER SHOP/BEAUTY SALON', 'CHA PARKING LOT', 'BASEMENT',
#        'VEHICLE - COMMERCIAL: TROLLEY BUS',
#        'COLLEGE / UNIVERSITY - RESIDENCE HALL', 'CLEANERS/LAUNDROMAT',
#        'DRIVEWAY', 'VEHICLE-COMMERCIAL - ENTERTAINMENT/PARTY BUS',
#        'COLLEGE / UNIVERSITY - GROUNDS', 'KENNEL', 'SCHOOL YARD', 'TRUCK',
#        'CHA STAIRWELL', 'HOSPITAL', 'DUMPSTER', 'CHA LOBBY', 'FARM',
#        'TAVERN', 'GARAGE/AUTO REPAIR', 'VEHICLE-COMMERCIAL - TROLLEY BUS',
#        'STAIRWELL', 'CTA SUBWAY STATION', 'LIQUOR STORE', 'LIVERY AUTO',
#        'VESTIBULE', 'PUBLIC HIGH SCHOOL', 'EXPRESSWAY EMBANKMENT', 'CLUB',
#        'WOODED AREA', 'GOVERNMENT BUILDING', 'RAILROAD PROPERTY',
#        'CHA PLAY LOT', 'NURSING HOME', 'HOTEL', 'MOTEL',
#        'VEHICLE - COMMERCIAL: ENTERTAINMENT / PARTY BUS', 'LAKE',
#        'LIVERY STAND OFFICE', 'TAXI CAB', 'CTA PROPERTY', 'TRAILER',
#        'BANQUET HALL', 'POOLROOM', 'CHA BREEZEWAY', 'RIVER',
#        'HORSE STABLE', 'PRAIRIE', 'TRUCKING TERMINAL', 'FACTORY', 'SEWER'],
#       dtype=object)

# %% [markdown]
# Finding where most crimes occur

# %% [markdown]
# We then looked at where most of these crimes usually occur as this could be helpful in determining where to station the police force. For this I used the following code:

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y= 'Location Description', data = df, order = df['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# The above graph gave us important insights showing that most of the crimes occur in streets, residence of people or apartment. Highest rate of crime is done on street,residence,apartment and sidewalk.

# %%
df.groupby([df['Location Description']]).size().sort_values(ascending=False)
# Out:
# Location Description
# STREET                586599
# RESIDENCE             378126
# APARTMENT             250301
# SIDEWALK              214966
# OTHER                  79863
#                        ...
# CHA PLAY LOT               1
# CHA BREEZEWAY              1
# BANQUET HALL               1
# RIVER                      1
# CTA SUBWAY STATION         1
# Length: 198, dtype: int64

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y= 'Primary Type', data = df, order = df['Primary Type'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Primary Type'>

# %% [markdown]
# The above plot display the most top ten crime Type and THEFT is leading followed by BATTERY, CRIMINAL DAMAGE, NACORTICS or ASSAULT.

# %%
types = df.groupby([df['Primary Type']]).size().sort_values(ascending=False)
types
# Out:
# Primary Type
# THEFT                                473224
# BATTERY                              416910
# CRIMINAL DAMAGE                      258651
# NARCOTICS                            219441
# ASSAULT                              147048
# OTHER OFFENSE                        140514
# BURGLARY                             124678
# MOTOR VEHICLE THEFT                  104919
# DECEPTIVE PRACTICE                    92874
# ROBBERY                               85272
# CRIMINAL TRESPASS                     63200
# WEAPONS VIOLATION                     30071
# PROSTITUTION                          20565
# PUBLIC PEACE VIOLATION                15433
# OFFENSE INVOLVING CHILDREN            15266
# SEX OFFENSE                            8259
# CRIM SEXUAL ASSAULT                    7904
# INTERFERENCE WITH PUBLIC OFFICER       5477
# LIQUOR LAW VIOLATION                   4420
# GAMBLING                               4308
# ARSON                                  3865
# HOMICIDE                               3597
# KIDNAPPING                             2155
# CRIMINAL SEXUAL ASSAULT                1414
# INTIMIDATION                           1385
# STALKING                               1318
# CONCEALED CARRY LICENSE VIOLATION       304
# OBSCENITY                               215
# PUBLIC INDECENCY                         58
# NON-CRIMINAL                             44
# OTHER NARCOTIC VIOLATION                 31
# HUMAN TRAFFICKING                        28
# NON - CRIMINAL                           12
# RITUALISM                                10
# NON-CRIMINAL (SUBJECT SPECIFIED)          2
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Block', 'Primary Type', 'Description', 'Location Description',
#        'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code', 'Year',
#        'Location'],
#       dtype='object')

# %%
# convert dates to pandas datetime format
df.Date = pd.to_datetime(df.Date, format='%m/%d/%Y %I:%M:%S %p')
# setting the index to be the date will help us a lot later on
df.index = pd.DatetimeIndex(df.Date)

# %%
plt.figure(figsize=(20,10))
df.resample('M').size().plot(legend=False)
plt.title('Number of crimes per month (2001 - 2022)')
plt.xlabel('Months')
plt.ylabel('Number of crimes')
plt.show()

# %% [markdown]
# The above pattern shows there is sharp decrease in crime rate from 2009 till date.

# %% [markdown]
# Determining the pattern of crimes

# %% [markdown]
# This part of analysis can be further divided into various subdivisions. We decided to analyze the crime division on:

# %% [markdown]
# monthly basis

# %% [markdown]
# yearly basis

# %% [markdown]
# patterns of each crime over the years

# %% [markdown]
# Crimes occurring per month over the years

# %%
plt.figure(figsize=(20,20))
df.groupby([df.index.month]).size().plot(kind='barh')
plt.ylabel('Months of the year')
plt.xlabel('Number of crimes')
plt.title('Number of crimes by month of the year')
plt.show()

# %% [markdown]
# Here we can also see the distribution of total number of crimes by months. “July” recorded the highest number of crimes reported.

# %% [markdown]
# Repeating the same analysis for days of the week.

# %%
days = ['Monday','Tuesday','Wednesday',  'Thursday', 'Friday', 'Saturday', 'Sunday']
df.groupby([df.index.dayofweek]).size().plot(kind='barh')
plt.ylabel('Days of the week')
plt.yticks(np.arange(7), days)
plt.xlabel('Number of crimes')
plt.title('Number of crimes by day of the week')
plt.show()

# %% [markdown]
# Here we can also see the distribution of total number of crimes by days of the week. “FRIDAY” recorded the highest number of crimes reported. Effectively, the above graphy had proved that the more dangerous months in the city of chicago are in summer. This analysis gives us other viewpoint.

# %%
plt.figure(figsize=(20,20))
df.groupby([df.index.hour]).size().plot.bar()
plt.title('Crime Per Hour')
plt.xlabel('Hour')
plt.ylabel('Number of Crimes Acts')
plt.show()

# %% [markdown]
# What are the most prevalent crimes in Chicago?

# %% [markdown]
# To predict the next crime type I needed to look into what the most common crimes were. First, I looked at an overall picture of how frequent every crime was. To do this, I created a seaborn factor plot showing the primary type against its count. I showed the top 20 to ease the analysis.

# %%
plt.figure(figsize = (15, 10))
sns.countplot(y= 'Primary Type', data = df, order = df['Primary Type'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Primary Type'>

# %% [markdown]
# This graph shows the type of crime plotted against its count. You can see the most common, by far, is theft, followed by battery, criminal damage, narcotics, assault, and beyond. It was interesting to see the magnitude to which theft and battery were by far the most common crimes.

# %% [markdown]
# Upon seeing the frequency of theft, I wanted to break things down further and see what type of theft was the most common. To do this, I created a new dataframe with only theft data in it through filtering for the primary type of theft.

# %%
s = df[['Primary Type']]

# %%
s
# Out:
#                           Primary Type
# Date
# 2008-07-26 14:30:00    CRIMINAL DAMAGE
# 2018-07-31 10:57:00  WEAPONS VIOLATION
# 2007-04-27 10:30:00           BURGLARY
# 2018-07-23 08:55:00            ASSAULT
# 2021-07-11 06:40:00            ASSAULT
# ...                                ...
# 2016-10-14 14:35:00            ASSAULT
# 2001-09-11 22:20:00            BATTERY
# 2006-05-10 19:49:00            ASSAULT
# 2017-10-18 22:30:00  CRIMINAL TRESPASS
# 2004-06-09 20:19:28          NARCOTICS
#
# [2252872 rows x 1 columns]

# %%
#extracting crimes which are theft and doing analysis on them
df_theft = df[df['Primary Type'] == 'THEFT']
df_theft.head()
# Out:
#                      Unnamed: 0                Date                 Block Primary Type  \
# Date
# 2001-08-21 00:00:00           5 2001-08-21 00:00:00         003XX W 28 PL        THEFT
# 2004-07-23 00:00:00          17 2004-07-23 00:00:00      009XX W GRACE ST        THEFT
# 2008-10-23 20:00:00          23 2008-10-23 20:00:00  003XX S MICHIGAN AVE        THEFT
# 2013-10-26 13:45:00          28 2013-10-26 13:45:00  008XX N MICHIGAN AVE        THEFT
# 2020-12-19 00:00:00          34 2020-12-19 00:00:00   005XX W DIVISION ST        THEFT
#
#                         Description          Location Description  Arrest  Domestic  Beat  \
# Date
# 2001-08-21 00:00:00       OVER $500                        STREET       0         0  2113
# 2004-07-23 00:00:00  $500 AND UNDER                         OTHER       0         0  2324
# 2008-10-23 20:00:00  $500 AND UNDER                 PARK PROPERTY       0         0   123
# 2013-10-26 13:45:00  POCKET-PICKING  GOVERNMENT BUILDING/PROPERTY       0         0  1833
# 2020-12-19 00:00:00   FROM BUILDING                     APARTMENT       0         0  1823
#
#                      District       Ward  Community Area FBI Code  Year  \
# Date
# 2001-08-21 00:00:00       2.0  22.713025       37.546407       06  2001
# 2004-07-23 00:00:00      19.0  44.000000        6.000000       06  2004
# 2008-10-23 20:00:00       1.0   2.000000       32.000000       06  2008
# 2013-10-26 13:45:00      18.0  42.000000        8.000000       06  2013
# 2020-12-19 00:00:00      18.0  27.000000        8.000000       06  2020
#
#                                           Location
# Date
# 2001-08-21 00:00:00  (41.842450075, -87.635700695)
# 2004-07-23 00:00:00   (41.95113401, -87.653750509)
# 2008-10-23 20:00:00  (41.877959571, -87.624313409)
# 2013-10-26 13:45:00  (41.898767916, -87.624116333)
# 2020-12-19 00:00:00   (41.903726889, -87.64259764)

# %%
#drawing the countplot for showing description of theft which had happened 

plt.figure(figsize = (15, 12))
sns.countplot(y = df_theft['Description'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Description'>

# %% [markdown]
# This plot shows the dominance of $500 and under crimes within the theft category. This led me to see that “petty theft”, or small-scale theft, is the most common crime in Chicago from 2001–2021.

# %% [markdown]
# Now that I knew small theft (less than $500) was the most common type of crime, I wanted to see where this usually happened. To do this, I created a graph showing the location breakdown of small theft crimes.

# %%
#creating a new dataframe which consists of description sorted on the basis of their number
new_df_theft = pd.DataFrame({'Counts' : df_theft['Description'].value_counts(), 'Description' : df_theft['Description'].value_counts().index})
new_df_theft.reset_index(inplace=True)
new_df_theft = new_df_theft.drop(columns = ['index'], axis = 1)
new_df_theft.head()
# Out:
#    Counts                    Description
# 0  183061                 $500 AND UNDER
# 1  117821                      OVER $500
# 2   74599                  FROM BUILDING
# 3   58595                   RETAIL THEFT
# 4   12042  FINANCIAL ID THEFT: OVER $300

# %% [markdown]
# Where do small theft crimes happen? That is the location of small theft crime.

# %% [markdown]
# To look into this question, I would plot the top 10 locations of small theft crimes with a seaborn factorplot.

# %%
#drawing the countplot for showing Location Description of theft which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = df_theft['Location Description'], data = df, order = df_theft['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# The above graph shows that the most common place, by far, for small theft is the street. This leads me to infer theft is likely from stores and retail areas on the street, or potentially from individuals and persons on the street.

# %% [markdown]
# Where do other crimes besides theft tend to occur?

# %% [markdown]
# I was curious to see where other crimes besides theft tended to occur. I looked more closely at some of the more popular crimes, and also some more extreme crimes that I was curious to explore. To do this, I created several more dataframes for different types of crime. First, I created dataframes for the top 4 most popular crimes behind theft: battery, criminal damage, narcotics, and assault. Next, I created dataframes for other crimes I was interested to look into. These were sex offense, deception, burglary, arson, child-involved crimes, homicide, and kidnapping. By creating these dataframes, not only could I look at the locations of these crimes, but I could continue to use these dataframes throughout the rest of my analysis.

# %% [markdown]
# First, I looked into the four most popular types of crime and their locations behind theft: Battery Crimes, Criminal Damage, Narcotics, and Assault.

# %%
#extracting crimes which are Battery and doing analysis on them
df_BATTERY = df[df['Primary Type'] == 'BATTERY']
df_BATTERY.head()
# Out:
#                      Unnamed: 0                Date                     Block Primary Type  \
# Date
# 2008-10-26 17:00:00          11 2008-10-26 17:00:00        058XX S KEDZIE AVE      BATTERY
# 2015-06-28 03:50:00          16 2015-06-28 03:50:00         047XX W FULTON ST      BATTERY
# 2002-01-02 17:00:00          19 2002-01-02 17:00:00          023XX S STATE ST      BATTERY
# 2002-10-19 21:15:00          21 2002-10-19 21:15:00       133XX S BRANDON AVE      BATTERY
# 2020-04-26 13:55:00          32 2020-04-26 13:55:00  053XX W BLOOMINGDALE AVE      BATTERY
#
#                                  Description Location Description  Arrest  Domestic  Beat  \
# Date
# 2008-10-26 17:00:00  DOMESTIC BATTERY SIMPLE            APARTMENT       0         1   822
# 2015-06-28 03:50:00  DOMESTIC BATTERY SIMPLE            APARTMENT       0         1  1113
# 2002-01-02 17:00:00                   SIMPLE        CHA APARTMENT       0         1  2113
# 2002-10-19 21:15:00                   SIMPLE               STREET       0         0   433
# 2020-04-26 13:55:00  DOMESTIC BATTERY SIMPLE            RESIDENCE       0         1  2532
#
#                      District       Ward  Community Area FBI Code  Year  \
# Date
# 2008-10-26 17:00:00       8.0  14.000000       63.000000      08B  2008
# 2015-06-28 03:50:00      11.0  28.000000       25.000000      08B  2015
# 2002-01-02 17:00:00       1.0  22.713025       37.546407      08B  2002
# 2002-10-19 21:15:00       4.0  10.000000       55.000000      08B  2002
# 2020-04-26 13:55:00      25.0  37.000000       25.000000      08B  2020
#
#                                           Location
# Date
# 2008-10-26 17:00:00   (41.78707194, -87.703370418)
# 2015-06-28 03:50:00   (41.88537469, -87.743742141)
# 2002-01-02 17:00:00  (41.850517353, -87.627031661)
# 2002-10-19 21:15:00   (41.653220991, -87.54591594)
# 2020-04-26 13:55:00   (41.91310479, -87.759909733)

# %%
#drawing the countplot for showing Location Description of BATTERY which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = df_BATTERY ['Location Description'], data = df, order = df_BATTERY ['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# This graph shows the location of battery crimes. The most common location was an apartment, followed by residence, and then streets and sidewalk. This led me to infer most battery crimes were at the home, and then the streets. Other locations were insignificant.

# %%
#extracting crimes which are NARCOTICS and doing analysis on them
df_NARCOTICS = df[df['Primary Type'] == 'NARCOTICS']
df_NARCOTICS.head()
# Out:
#                      Unnamed: 0                Date                   Block Primary Type  \
# Date
# 2014-12-02 11:48:00           7 2014-12-02 11:48:00     043XX W POTOMAC AVE    NARCOTICS
# 2016-06-18 23:15:00           9 2016-06-18 23:15:00  021XX N CALIFORNIA AVE    NARCOTICS
# 2014-01-18 09:00:00          10 2014-01-18 09:00:00     031XX W WARREN BLVD    NARCOTICS
# 2003-04-06 15:00:00          18 2003-04-06 15:00:00       002XX N LOREL AVE    NARCOTICS
# 2015-12-16 17:00:00          36 2015-12-16 17:00:00      031XX S HALSTED ST    NARCOTICS
#
#                                       Description             Location Description  Arrest  \
# Date
# 2014-12-02 11:48:00  POSS: CANNABIS 30GMS OR LESS                            ALLEY       1
# 2016-06-18 23:15:00  POSS: CANNABIS 30GMS OR LESS  POLICE FACILITY/VEH PARKING LOT       1
# 2014-01-18 09:00:00  MANU/DELIVER: HEROIN (WHITE)                         SIDEWALK       1
# 2003-04-06 15:00:00                   POSS: CRACK                         SIDEWALK       1
# 2015-12-16 17:00:00                   POSS: CRACK  POLICE FACILITY/VEH PARKING LOT       1
#
#                      Domestic  Beat  District  Ward  Community Area FBI Code  Year  \
# Date
# 2014-12-02 11:48:00         0  2534      25.0  37.0            23.0       18  2014
# 2016-06-18 23:15:00         0  1414      14.0  35.0            22.0       18  2016
# 2014-01-18 09:00:00         0  1222      12.0  28.0            27.0       18  2014
# 2003-04-06 15:00:00         0  1523      15.0  28.0            25.0       18  2003
# 2015-12-16 17:00:00         0   913       9.0  11.0            60.0       18  2015
#
#                                           Location
# Date
# 2014-12-02 11:48:00  (41.904351902, -87.734347128)
# 2016-06-18 23:15:00   (41.921021491, -87.69730355)
# 2014-01-18 09:00:00  (41.881907051, -87.704628385)
# 2003-04-06 15:00:00  (41.884902673, -87.758902361)
# 2015-12-16 17:00:00  (41.837489008, -87.646264459)

# %%
#drawing the countplot for showing Location Description of NARCOTICS which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = df_NARCOTICS ['Location Description'], data = df, order = df_NARCOTICS ['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# From the above graph i could infer that many of these narcotics charges are either dealing or using drugs, so it makes logical sense this would happen on the streets or sidewalks.

# %%
#extracting crimes which are ASSAULT and doing analysis on them
df_ASSAULT = df[df['Primary Type'] == 'ASSAULT']
df_ASSAULT.head()
# Out:
#                      Unnamed: 0                Date                Block Primary Type  \
# Date
# 2018-07-23 08:55:00           3 2018-07-23 08:55:00   0000X N KEELER AVE      ASSAULT
# 2021-07-11 06:40:00           4 2021-07-11 06:40:00  016XX W HARRISON ST      ASSAULT
# 2017-11-08 13:10:00          26 2017-11-08 13:10:00   025XX W BERWYN AVE      ASSAULT
# 2011-08-11 13:45:00          51 2011-08-11 13:45:00     093XX S LOWE AVE      ASSAULT
# 2012-07-29 07:05:00          60 2012-07-29 07:05:00   066XX W BELDEN AVE      ASSAULT
#
#                               Description                    Location Description  Arrest  \
# Date
# 2018-07-23 08:55:00                SIMPLE            NURSING HOME/RETIREMENT HOME       0
# 2021-07-11 06:40:00  AGGRAVATED - HANDGUN  PARKING LOT / GARAGE (NON RESIDENTIAL)       0
# 2017-11-08 13:10:00                SIMPLE                                  STREET       0
# 2011-08-11 13:45:00                SIMPLE                               RESIDENCE       0
# 2012-07-29 07:05:00                SIMPLE            NURSING HOME/RETIREMENT HOME       0
#
#                      Domestic  Beat  District  Ward  Community Area FBI Code  Year  \
# Date
# 2018-07-23 08:55:00         0  1115      11.0  28.0            26.0      08A  2018
# 2021-07-11 06:40:00         0  1231      12.0  27.0            28.0      04A  2021
# 2017-11-08 13:10:00         0  2011      20.0  40.0             4.0      08A  2017
# 2011-08-11 13:45:00         0  2223      22.0  21.0            73.0      08A  2011
# 2012-07-29 07:05:00         0  2512      25.0  36.0            18.0      08A  2012
#
#                                           Location
# Date
# 2018-07-23 08:55:00  (41.881217483, -87.730589961)
# 2021-07-11 06:40:00  (41.874173691, -87.668082118)
# 2017-11-08 13:10:00  (41.977685067, -87.693047613)
# 2011-08-11 13:45:00   (41.724631501, -87.63965452)
# 2012-07-29 07:05:00    (41.9211998, -87.792036506)

# %%
#drawing the countplot for showing Location Description of ASSAULT which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = df_ASSAULT ['Location Description'], data = df, order = df_ASSAULT ['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# This graph shows the most common location of assault crimes in Chicago. I thought it was interesting to see that the street areas (street & sidewalk) were nearly even with home areas (residence & apartment) in terms of this particular crime.

# %% [markdown]
# This analysis prompted me to infer that someone is likely to suffer from an assault on the streets as does in their homes. This called for further analysis on how different types of assaults would differ between streets and homes.

# %%
#creating a new dataframe which consists of description sorted on the basis of their number
new_df_ASSAULT = pd.DataFrame({'Counts' : df_ASSAULT['Description'].value_counts(), 'Description' : df_ASSAULT['Description'].value_counts().index})
new_df_ASSAULT.reset_index(inplace=True)
new_df_ASSAULT = new_df_ASSAULT.drop(columns = ['index'], axis = 1)
new_df_ASSAULT.head()
# Out:
#    Counts                     Description
# 0  100636                          SIMPLE
# 1   14754             AGGRAVATED: HANDGUN
# 2    9599  AGGRAVATED:KNIFE/CUTTING INSTR
# 3    7856   AGGRAVATED: OTHER DANG WEAPON
# 4    4531     PRO EMP HANDS NO/MIN INJURY

# %%
#drawing the countplot for showing Description of ASSAULT which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = df_ASSAULT ['Description'], data = df, order = df_ASSAULT ['Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Description'>

# %% [markdown]
# This showed that the vast majority of assaults were “simple”, followed by handgun and then knife/cutting.

# %%
#extracting crimes which are Simple ASSAULT and doing analysis on them
SimpleAssaultDf = df[df['Description'] == 'SIMPLE']
SimpleAssaultDf.head()
# Out:
#                      Unnamed: 0                Date                 Block Primary Type  \
# Date
# 2018-07-23 08:55:00           3 2018-07-23 08:55:00    0000X N KEELER AVE      ASSAULT
# 2002-01-02 17:00:00          19 2002-01-02 17:00:00      023XX S STATE ST      BATTERY
# 2002-10-19 21:15:00          21 2002-10-19 21:15:00   133XX S BRANDON AVE      BATTERY
# 2017-11-08 13:10:00          26 2017-11-08 13:10:00    025XX W BERWYN AVE      ASSAULT
# 2006-01-08 06:55:00          42 2006-01-08 06:55:00  077XX S PHILLIPS AVE      BATTERY
#
#                     Description          Location Description  Arrest  Domestic  Beat  District  \
# Date
# 2018-07-23 08:55:00      SIMPLE  NURSING HOME/RETIREMENT HOME       0         0  1115      11.0
# 2002-01-02 17:00:00      SIMPLE                 CHA APARTMENT       0         1  2113       1.0
# 2002-10-19 21:15:00      SIMPLE                        STREET       0         0   433       4.0
# 2017-11-08 13:10:00      SIMPLE                        STREET       0         0  2011      20.0
# 2006-01-08 06:55:00      SIMPLE                      SIDEWALK       0         0   421       4.0
#
#                           Ward  Community Area FBI Code  Year                       Location
# Date
# 2018-07-23 08:55:00  28.000000       26.000000      08A  2018  (41.881217483, -87.730589961)
# 2002-01-02 17:00:00  22.713025       37.546407      08B  2002  (41.850517353, -87.627031661)
# 2002-10-19 21:15:00  10.000000       55.000000      08B  2002   (41.653220991, -87.54591594)
# 2017-11-08 13:10:00  40.000000        4.000000      08A  2017  (41.977685067, -87.693047613)
# 2006-01-08 06:55:00   7.000000       43.000000      08B  2006  (41.754533775, -87.565074073)

# %%
#drawing the countplot for showing Location Description of Simple ASSAULT which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = SimpleAssaultDf ['Location Description'], data = df, order = SimpleAssaultDf ['Location Description']
# Out:
#   Input In [52]
#     sns.countplot(y = SimpleAssaultDf ['Location Description'], data = df, order = SimpleAssaultDf ['Location Description']
#                                                                                                                            ^
# SyntaxError: unexpected EOF while parsing

# %%
#extracting crimes which are AGGRAVATED: HANDGUN ASSAULT and doing analysis on them
AGGRAVATEDAssaultDf = df[df['Description'] == 'AGGRAVATED: HANDGUN']
AGGRAVATEDAssaultDf.head()
# Out:
#                      Unnamed: 0                Date                  Block Primary Type  \
# Date
# 2011-10-12 18:13:00          70 2011-10-12 18:13:00     061XX S WABASH AVE      BATTERY
# 2003-05-05 15:40:00         154 2003-05-05 15:40:00       005XX W 103RD ST      BATTERY
# 2003-09-28 06:23:00         284 2003-09-28 06:23:00     019XX S KEDZIE AVE      ASSAULT
# 2016-12-11 04:00:00         306 2016-12-11 04:00:00      021XX S HOYNE AVE      ASSAULT
# 2003-06-24 21:30:00         413 2003-06-24 21:30:00  016XX N MAPLEWOOD AVE      ASSAULT
#
#                              Description Location Description  Arrest  Domestic  Beat  District  \
# Date
# 2011-10-12 18:13:00  AGGRAVATED: HANDGUN             SIDEWALK       0         0   311       3.0
# 2003-05-05 15:40:00  AGGRAVATED: HANDGUN   SMALL RETAIL STORE       0         0  2232      22.0
# 2003-09-28 06:23:00  AGGRAVATED: HANDGUN            RESIDENCE       1         0  1022      10.0
# 2016-12-11 04:00:00  AGGRAVATED: HANDGUN               STREET       0         0  1234      12.0
# 2003-06-24 21:30:00  AGGRAVATED: HANDGUN             SIDEWALK       1         0  1434      14.0
#
#                      Ward  Community Area FBI Code  Year                       Location
# Date
# 2011-10-12 18:13:00  20.0            40.0      04B  2011  (41.783257178, -87.623784773)
# 2003-05-05 15:40:00  34.0            49.0      04B  2003   (41.70698975, -87.637178102)
# 2003-09-28 06:23:00  24.0            29.0      04A  2003   (41.85470167, -87.705339043)
# 2016-12-11 04:00:00  25.0            31.0      04A  2016  (41.853746781, -87.678336552)
# 2003-06-24 21:30:00   1.0            24.0      04A  2003  (41.911145069, -87.690906202)

# %%
#drawing the countplot for showing Location Description of AGGRAVATED: HANDGUN ASSAULT which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = AGGRAVATEDAssaultDf ['Location Description'], data = df, order = AGGRAVATEDAssaultDf ['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# This graph shows the most common place for handgun assaults. This shows that the most common location for these is at the streets, especially street followed by sidewalk.

# %%
#extracting crimes which are AGGRAVATED: HANDGUN ASSAULT and doing analysis on them
KNIFE_CUTTINGINSTRAssaultDf = df[df['Description'] == 'AGGRAVATED:KNIFE/CUTTING INSTR']
KNIFE_CUTTINGINSTRAssaultDf.head()
# Out:
#                      Unnamed: 0                Date                                Block  \
# Date
# 2009-04-04 09:45:00          89 2009-04-04 09:45:00                  077XX S ASHLAND AVE
# 2006-05-29 11:45:00          96 2006-05-29 11:45:00                  066XX S LANGLEY AVE
# 2017-11-02 03:24:00         151 2017-11-02 03:24:00  053XX S DR MARTIN LUTHER KING JR DR
# 2006-09-12 20:53:00         889 2006-09-12 20:53:00                     122XX S STATE ST
# 2013-01-27 08:05:00         945 2013-01-27 08:05:00                 031XX S KILBOURN AVE
#
#                     Primary Type                     Description Location Description  Arrest  \
# Date
# 2009-04-04 09:45:00      BATTERY  AGGRAVATED:KNIFE/CUTTING INSTR            APARTMENT       0
# 2006-05-29 11:45:00      BATTERY  AGGRAVATED:KNIFE/CUTTING INSTR            APARTMENT       0
# 2017-11-02 03:24:00      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR            APARTMENT       0
# 2006-09-12 20:53:00      ASSAULT  AGGRAVATED:KNIFE/CUTTING INSTR            RESIDENCE       1
# 2013-01-27 08:05:00      BATTERY  AGGRAVATED:KNIFE/CUTTING INSTR             SIDEWALK       0
#
#                      Domestic  Beat  District  Ward  Community Area FBI Code  Year  \
# Date
# 2009-04-04 09:45:00         0   611       6.0  17.0            71.0      04B  2009
# 2006-05-29 11:45:00         0   321       3.0  20.0            42.0      04B  2006
# 2017-11-02 03:24:00         1   231       2.0   3.0            40.0      04A  2017
# 2006-09-12 20:53:00         0   532       5.0   9.0            53.0      04A  2006
# 2013-01-27 08:05:00         0  1031      10.0  22.0            30.0      04B  2013
#
#                                           Location
# Date
# 2009-04-04 09:45:00   (41.75322329, -87.663505427)
# 2006-05-29 11:45:00  (41.774334552, -87.608251104)
# 2017-11-02 03:24:00   (41.79799269, -87.616063748)
# 2006-09-12 20:53:00  (41.672046782, -87.622485541)
# 2013-01-27 08:05:00  (41.836657193, -87.736560384)

# %%
#drawing the countplot for showing Location Description of AGGRAVATED:KNIFE/CUTTING INSTR ASSAULT which had happened 
plt.figure(figsize = (20, 20))
sns.countplot(y = KNIFE_CUTTINGINSTRAssaultDf ['Location Description'], data = df, order = KNIFE_CUTTINGINSTRAssaultDf ['Location Description'].value_counts().iloc[:10].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Location Description'>

# %% [markdown]
# The above graph shows the most common places for knife/cutting assaults to happen. this particular assault happened in both streets and homes. This is very different from both simple and gun assaults, which were far more common in the streets (street/sidewalk) than the apartment.

# %% [markdown]
# Summary: My findings looking at the different types of assaults and their locations, I found that knife/cutting assaults were likely to happen on the streets, where gun assaults and simple assaults were more likely to happen at the streets. Knife/cutting assaults were more likely to occur at both streets(street and sidewalk) and home(resisdence). While on the srteet, you are more likely to face a gun or simple assault.

# %% [markdown]
# Analysis by hours

# %%
df.head()
# Out:
#                      Unnamed: 0                Date                 Block       Primary Type  \
# Date
# 2008-07-26 14:30:00           0 2008-07-26 14:30:00  085XX S MUSKEGON AVE    CRIMINAL DAMAGE
# 2018-07-31 10:57:00           1 2018-07-31 10:57:00     092XX S ELLIS AVE  WEAPONS VIOLATION
# 2007-04-27 10:30:00           2 2007-04-27 10:30:00     062XX N TRIPP AVE           BURGLARY
# 2018-07-23 08:55:00           3 2018-07-23 08:55:00    0000X N KEELER AVE            ASSAULT
# 2021-07-11 06:40:00           4 2021-07-11 06:40:00   016XX W HARRISON ST            ASSAULT
#
#                                   Description                    Location Description  Arrest  \
# Date
# 2008-07-26 14:30:00                TO VEHICLE                                  STREET       0
# 2018-07-31 10:57:00  UNLAWFUL POSS AMMUNITION                               POOL ROOM       1
# 2007-04-27 10:30:00            FORCIBLE ENTRY                               RESIDENCE       1
# 2018-07-23 08:55:00                    SIMPLE            NURSING HOME/RETIREMENT HOME       0
# 2021-07-11 06:40:00      AGGRAVATED - HANDGUN  PARKING LOT / GARAGE (NON RESIDENTIAL)       0
#
#                      Domestic  Beat  District  Ward  Community Area FBI Code  Year  \
# Date
# 2008-07-26 14:30:00         0   423       4.0  10.0            46.0       14  2008
# 2018-07-31 10:57:00         0   413       4.0   8.0            47.0       15  2018
# 2007-04-27 10:30:00         0  1711      17.0  39.0            12.0       05  2007
# 2018-07-23 08:55:00         0  1115      11.0  28.0            26.0      08A  2018
# 2021-07-11 06:40:00         0  1231      12.0  27.0            28.0      04A  2021
#
#                                           Location
# Date
# 2008-07-26 14:30:00  (41.739979622, -87.555120042)
# 2018-07-31 10:57:00  (41.726922145, -87.599746995)
# 2007-04-27 10:30:00  (41.994137622, -87.734959049)
# 2018-07-23 08:55:00  (41.881217483, -87.730589961)
# 2021-07-11 06:40:00  (41.874173691, -87.668082118)

# %%
# convert dates to pandas datetime format
df.Date = pd.to_datetime(df.Date, format='%m/%d/%Y %I:%M:%S %p')
# setting the index to be the date will help us a lot later on
df.index = pd.DatetimeIndex(df.Date)

# %%
dfhours = df.resample('h').count()

dfhours.head(5)
# Out:
#                      Unnamed: 0  Date  Block  Primary Type  Description  Location Description  \
# Date
# 2001-01-01 00:00:00         114   114    114           114          114                   114
# 2001-01-01 01:00:00          32    32     32            32           32                    32
# 2001-01-01 02:00:00          22    22     22            22           22                    22
# 2001-01-01 03:00:00          24    24     24            24           24                    24
# 2001-01-01 04:00:00          20    20     20            20           20                    20
#
#                      Arrest  Domestic  Beat  District  Ward  Community Area  FBI Code  Year  \
# Date
# 2001-01-01 00:00:00     114       114   114       114   114             114       114   114
# 2001-01-01 01:00:00      32        32    32        32    32              32        32    32
# 2001-01-01 02:00:00      22        22    22        22    22              22        22    22
# 2001-01-01 03:00:00      24        24    24        24    24              24        24    24
# 2001-01-01 04:00:00      20        20    20        20    20              20        20    20
#
#                      Location
# Date
# 2001-01-01 00:00:00       114
# 2001-01-01 01:00:00        32
# 2001-01-01 02:00:00        22
# 2001-01-01 03:00:00        24
# 2001-01-01 04:00:00        20

# %%
datetime_column = pd.to_datetime(df['Date'], format='%m/%d/%Y %I:%M:%S %p')

# %%
df['month'] = datetime_column.dt.month
df['day'] = datetime_column.dt.day
df['weekday'] = datetime_column.dt.weekday.astype('category')
df['hour'] = datetime_column.dt.hour
df.head()
# Out:
#                      Unnamed: 0                Date                 Block       Primary Type  \
# Date
# 2008-07-26 14:30:00           0 2008-07-26 14:30:00  085XX S MUSKEGON AVE    CRIMINAL DAMAGE
# 2018-07-31 10:57:00           1 2018-07-31 10:57:00     092XX S ELLIS AVE  WEAPONS VIOLATION
# 2007-04-27 10:30:00           2 2007-04-27 10:30:00     062XX N TRIPP AVE           BURGLARY
# 2018-07-23 08:55:00           3 2018-07-23 08:55:00    0000X N KEELER AVE            ASSAULT
# 2021-07-11 06:40:00           4 2021-07-11 06:40:00   016XX W HARRISON ST            ASSAULT
#
#                                   Description                    Location Description  Arrest  \
# Date
# 2008-07-26 14:30:00                TO VEHICLE                                  STREET       0
# 2018-07-31 10:57:00  UNLAWFUL POSS AMMUNITION                               POOL ROOM       1
# 2007-04-27 10:30:00            FORCIBLE ENTRY                               RESIDENCE       1
# 2018-07-23 08:55:00                    SIMPLE            NURSING HOME/RETIREMENT HOME       0
# 2021-07-11 06:40:00      AGGRAVATED - HANDGUN  PARKING LOT / GARAGE (NON RESIDENTIAL)       0
#
#                      Domestic  Beat  District  Ward  Community Area FBI Code  Year  \
# Date
# 2008-07-26 14:30:00         0   423       4.0  10.0            46.0       14  2008
# 2018-07-31 10:57:00         0   413       4.0   8.0            47.0       15  2018
# 2007-04-27 10:30:00         0  1711      17.0  39.0            12.0       05  2007
# 2018-07-23 08:55:00         0  1115      11.0  28.0            26.0      08A  2018
# 2021-07-11 06:40:00         0  1231      12.0  27.0            28.0      04A  2021
#
#                                           Location  month  day weekday  hour
# Date
# 2008-07-26 14:30:00  (41.739979622, -87.555120042)      7   26       5    14
# 2018-07-31 10:57:00  (41.726922145, -87.599746995)      7   31       1    10
# 2007-04-27 10:30:00  (41.994137622, -87.734959049)      4   27       4    10
# 2018-07-23 08:55:00  (41.881217483, -87.730589961)      7   23       0     8
# 2021-07-11 06:40:00  (41.874173691, -87.668082118)      7   11       6     6

# %%
import seaborn as sns
sns.set_theme(style="ticks")

for cat_var in ['month', 'hour', 'weekday', 'Domestic', 'Arrest', 'District', 'Ward', 'Location Description']:
    if cat_var == 'weekday':
        # Sort by week
        order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    elif cat_var in ['District', 'Ward', 'Location Description']:
        # Sort by frequency
        order = df.groupby(by=cat_var).size().sort_values(ascending=False).index
    else:
        # Do not sort explicitly
        order = None
    sns.catplot(data=df, x=cat_var, kind='count', order=order)
    plt.xticks(rotation=90)
    
# Discoveries:
# - month: modal distribution; peaks July (=> maybe vacation time)
# - hour: most crimes during (late) daytime
# - weekday: slightly more crime on weekends
# - most crimes are non-domestic
# - most crimes do not lead to an arrest
# - There are some districts, and wards with more crime than other
# - 'Ward' is already hardly readible.
# - Sorting increases readability.

# %% [markdown]
# INSIGHTS AND EVALUATIONS

# %% [markdown]
# 1. Higher trend of crime during the summer months

# %% [markdown]
# A similar trend we see across our analysis shows that crime rates spike from July – August during the summer period. Some researchers reason that increased temperatures from the increased daylight hours can lengthen the amount of time people spend away from their homes, increasing the number of people in public and the amount of time that homes are left empty, creating a greater possibility of criminal activities.

# %% [markdown]
# Others point to the effect of students on summer vacation, who are otherwise occupied with schooling during other seasons; whereas others postulate that heat-induced discomfort could also make people more aggressive and is more likely to act out.

# %% [markdown]
# Analysis also showed the distribution of total number of crimes by days of the week. “FRIDAY” recorded the highest number of crimes reported. Effectively, i could infer that the more dangerous months in the city of chicago are in summer. This analysis gives us other viewpoint. The most common Type of crimes, by far, is theft, followed by battery, criminal damage, narcotics, assault, and beyond. It was interesting to see the magnitude to which theft and battery were by far the most common crimes. The most common location of the above crime types were either streets( street and sidewalk) and homes(residence and apartment).

# %% [markdown]
# 2. Gun related incidents are frequently reported with low arrest rates

# %% [markdown]
# My findings looking at the different types of assaults and their locations, I found that knife/cutting assaults were likely to happen on the streets, where gun assaults and simple assaults were more likely to happen at the streets. Knife/cutting assaults were more likely to occur at both street and sidewalk and home(resisdence). While on the srteet, you are more likely to face a gun or simple assault. Conclusion could be made that assault and robbery with handguns are the most highly reported incidents in Chicago. Most crimes are non-domestic and they do not lead to an arrest. There are some districts, and wards with more crime than other.

# %% [markdown]
# Periods of the day of different crimes occurances

# %% [markdown]
# Some crimes happened in the midday period between 10AM-2PM. Assault is less common than average, where weapons violations is slightly more common as robbery. Evening crimes happened from 6–10PM. Further, as the day has gone on, battery has become increasingly common and is closer to the amount of theft. Crimes at night happened between the hours of 10PM-2AM. Compared to the average and earlier hours of the day, battery has now become more common than theft and burglary and robbery continue to become less common. Additionally, narcotics seems to be the most common in the evening, from 6–10PM, perhaps when the daylight tends to drop as these crimes tend to occur on the street. Sexual assault is the most common in the very late night (2–6AM).

# %% [markdown]
# CONCLUSION

# %% [markdown]
# Chicago Police Department should be aware of the following Types of Crimes: theft, battery, criminal damage, narcotics, and assault. Also Knife/cutting assaults, a gun or simple assault are likely to occur either on the streets(street and sidewalk) or homes(residence and apartment). Police Department is hereby advised to deploy more tactical police squard to those crimes spotlight to prevent them happening. Special attension should be given to FRIDAY and weekend. And priod of occurence should be noted as highlighted above for effective operation. “Chicago Police Department is recommended to make use of data-driven command hubs known as Strategic Decision Support Centres and be installed in vaious department and districts. The centers link gunshot detection sensors and video to a system that can rapidly alert cops in the field to a shooting and identify potential suspects. The centers, operated by police and civilians from the University of Chicago Crime Lab, employ a predictive computer program called HunchLab to look at data such as crime incidents and proximity to liquor stores and gas stations. The software anticipates hot spots and suggests the deployment of officers to prevent retaliatory shootings.”
